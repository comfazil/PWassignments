# %% [markdown]
# ## Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %% [markdown]
# A Python library called Matplotlib offers a large range of tools and functions for making excellent visualisations, graphs, and plots. It is among the most widely used Python packages for data visualisation.
#
# Plots that can be plotted using pyplot :
#  - Line Plots
#  - Scatter Plot
#  - Pie Charts
#  - Bar Plots
#  - Histograms

# %% [markdown]
# ## Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data plot a scatter plot.
# 	import numpy as np
# 	np.random.seed(3)
# 	x = 3 + np.random.normal(0, 2, 50)
# 	y = 3 + np.random.normal(0, 2, len(x))
# ## Note: Also add title, xlabel, and ylabel to the plot.

# %% [markdown]
# A scatter plot is a sort of visualisation that uses individual data points to represent the relationship between two variables on a two-dimensional graph. A dot is used to represent each data point, and its location on the graph reflects the values of the two variables it represents.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(3)

x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

plt.scatter(x, y)

plt.title('Scatter Plot of X and Y')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# ## Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:
#
#     import numpy as np
# 	For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# 	For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# 	For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# 	For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %% [markdown]
# The subplot() function is used to create multiple plots in a single figure. It takes three arguments: the number of rows, the number of columns, and the index of the current subplot.

# %%
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])
x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])
x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])
x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

# %%
fig, axs = plt.subplots(2, 2)
axs[0, 0].plot(x1, y1)
axs[0, 0].set_title('Line 1')

axs[0, 1].plot(x2, y2)
axs[0, 1].set_title('Line 2')

axs[1, 0].plot(x3, y3)
axs[1, 0].set_title('Line 3')

axs[1, 1].plot(x4, y4)
axs[1, 1].set_title('Line 4')

plt.subplots_adjust(wspace=0.3, hspace=0.3)

plt.show()

# %% [markdown]
# ## Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
#
# 	import numpy as np
# 	company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# 	profit = np.array([3000, 8000, 1000, 10000])

# %% [markdown]
# A bar plot is a plot that presents categorical data with rectangular bars with lengths proportional to the values that they represent. It is used to compare the values of different categories.

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

plt.bar(company, profit)
plt.title("Profit of Companies")
plt.xlabel("Company")
plt.ylabel("Profit")
plt.show()

plt.barh(company, profit)
plt.title("Profit of Companies")
plt.xlabel("Profit")
plt.ylabel("Company")
plt.show()

# %% [markdown]
# ## Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
#
# 	box1 = np.random.normal(100, 10, 200)
# 	box2 = np.random.normal(90, 20, 200)

# %% [markdown]
# A box plot is a graphical representation of statistical data based on the five-number summary of a dataset: minimum, first quartile (Q1), median, third quartile (Q3), and maximum. It is used to visually summarize the distribution of a dataset and to detect any outliers.

# %%
import matplotlib.pyplot as plt
import numpy as np

box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

plt.boxplot([box1, box2])
plt.title("Box plot of Box 1 and Box 2")
plt.xlabel("Box")
plt.ylabel("Value")
plt.show()
