# %% [markdown]
# ## Q1. Load the flight price dataset and examine its dimensions. How many rows and columns does the dataset have?

# %%
import pandas as pd

# Load the flight price dataset
df = pd.read_excel('flight_price.xlsx')

# Examine the dimensions of the dataset
rows, columns = df.shape
print(f"The flight price dataset has {rows} rows and {columns} columns.")
# Out:
# The flight price dataset has 10683 rows and 11 columns.

# %% [markdown]
# ## Q2. What is the distribution of flight prices in the dataset? Create a histogram to visualize the distribution.

# %%
import matplotlib.pyplot as plt

# Create a histogram of flight prices
plt.hist(df['Price'], bins=20)
plt.xlabel('Flight Price')
plt.ylabel('Frequency')
plt.title('Distribution of Flight Prices')
plt.show()

# %% [markdown]
# ## Q3. What is the range of prices in the dataset? What is the minimum and maximum price?

# %%
# Calculate the minimum and maximum prices
min_price = df['Price'].min()
max_price = df['Price'].max()

print(f"The range of prices in the dataset is from ${min_price} to ${max_price}.")
# Out:
# The range of prices in the dataset is from $1759 to $79512.

# %% [markdown]
# ## Q4. How does the price of flights vary by airline? Create a boxplot to compare the prices of different airlines.

# %%
import seaborn as sns

# Create a boxplot of flight prices by airline
sns.boxplot(x='Airline', y='Price', data=df)
plt.xlabel('Airline')
plt.ylabel('Flight Price')
plt.title('Flight Prices by Airline')
plt.show()

# %% [markdown]
# ## Q5. Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how they may impact your analysis.

# %% [markdown]
# You can use the boxplot created in the previous question to identify potential outliers in the dataset. Outliers are data points that fall outside the whiskers of the boxplot and may impact your analysis by skewing the results or affecting the overall trends. You can further investigate these potential outliers to determine if they are valid data points or data entry errors. If necessary, you can decide to remove or treat these outliers before conducting further analysis to ensure more accurate results.

# %% [markdown]
# ## Q6. You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset to identify the peak travel season. What features would you analyze to identify the peak season, and how would you present your findings to your boss?

# %% [markdown]
# To identify the peak travel season from the Flight Price dataset, I would analyze the following features:
#
# Date/Time: I would examine the distribution of flight prices across different months or seasons to identify any patterns or trends. This could be done by creating line charts or bar charts to visualize the average flight prices over time.
#
# Departure/Arrival City: I would investigate if there are any specific departure or arrival cities that show higher flight prices during certain months or seasons. This could be done by creating bar charts or heatmaps to visualize the average flight prices by city and month/season.
#
# Holidays/Events: I would also check if there are any major holidays or events that coincide with higher flight prices. This could be done by creating a calendar of holidays or events and overlaying it with the flight price data to identify any spikes in prices during those periods.
#
# Airline: I would analyze if flight prices vary by airline during different months or seasons. This could be done by creating boxplots or violin plots to compare the distribution of flight prices among different airlines.
#
# Once I have analyzed the data and identified the peak travel season, I would present my findings to my boss using visualizations such as line charts, bar charts, heatmaps, and boxplots or violin plots, as appropriate. I would also provide a written summary of my findings, highlighting the key insights and conclusions related to the peak travel season, along with any recommendations or actionable insights based on the analysis.

# %% [markdown]
# ## Q7. You are a data analyst for a flight booking website, and you have been asked to analyze the Flight Price dataset to identify any trends in flight prices. What features would you analyze to identify these trends, and what visualizations would you use to present your findings to your team?

# %% [markdown]
# As a data analyst for a flight booking website, to identify trends in flight prices from the Flight Price dataset, I would analyze the following features:
#
# Date/Time: I would examine the overall trend of flight prices over time to identify any seasonal or cyclical patterns. This could be done by creating line charts or area charts to visualize the average flight prices over time.
#
# Departure/Arrival City: I would investigate if there are any specific departure or arrival cities that consistently show higher or lower flight prices. This could be done by creating bar charts or heatmaps to visualize the average flight prices by city.
#
# Duration of Stay: I would analyze if there are any trends in flight prices based on the duration of stay, such as shorter trips or longer trips. This could be done by creating boxplots or violin plots to compare the distribution of flight prices for different durations of stay.
#
# Booking Lead Time: I would examine if flight prices vary based on the booking lead time, i.e., the time between booking and departure. This could be done by creating scatter plots or line charts to visualize the relationship between booking lead time and flight prices.
#
# Airline: I would analyze if there are any significant differences in flight prices among different airlines. This could be done by creating boxplots or violin plots to compare the distribution of flight prices among different airlines.
#
# I would present my findings to my team using visualizations such as line charts, bar charts, heatmaps, boxplots, violin plots, scatter plots, or other appropriate visualizations. I would also provide a written summary of my findings, highlighting the key trends and insights related to flight prices, along with any recommendations or actionable insights based on the analysis.

# %% [markdown]
# ## Q8. You are a data scientist working for an airline company, and you have been asked to analyze the Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to identify these factors, and how would you present your findings to the management team?

# %% [markdown]
# As a data scientist working for an airline company, I would analyze the following features in the Flight Price dataset to identify the factors that affect flight prices:
#
# Departure/Arrival City: I would investigate if flight prices vary based on the departure or arrival city. This could be done by creating bar charts or heatmaps to visualize the average flight prices by city. This could help identify if certain cities have higher or lower flight prices, which could be influenced by factors such as demand, competition, and operational costs.
#
# Airline: I would analyze if there are any significant differences in flight prices among different airlines. This could be done by creating boxplots or violin plots to compare the distribution of flight prices among different airlines. This could help identify if there are any pricing strategies or competitive dynamics among airlines that impact flight prices.
#
# Date/Time: I would examine the overall trend of flight prices over time to identify any seasonal or cyclical patterns. This could be done by creating line charts or area charts to visualize the average flight prices over time. This could help identify if there are any specific months or seasons that consistently show higher or lower flight prices, which could be influenced by factors such as peak travel seasons, holidays, or other external factors.
#
# Duration of Stay: I would analyze if there are any trends in flight prices based on the duration of stay, such as shorter trips or longer trips. This could be done by creating boxplots or violin plots to compare the distribution of flight prices for different durations of stay. This could help identify if there are any pricing strategies or demand patterns based on trip durations.
#
# Booking Lead Time: I would examine if flight prices vary based on the booking lead time, i.e., the time between booking and departure. This could be done by creating scatter plots or line charts to visualize the relationship between booking lead time and flight prices. This could help identify if there are any pricing dynamics related to booking timing, such as last-minute bookings or early bookings.
#
# Once I have analyzed the data and identified the factors that affect flight prices, I would present my findings to the management team using a combination of visualizations such as bar charts, heatmaps, line charts, scatter plots, boxplots, or violin plots, as appropriate. I would also provide a written summary of my findings, highlighting the key insights and conclusions related to the factors affecting flight prices, along with any recommendations or actionable insights based on the analysis. I would aim to present the findings in a clear and concise manner, supported by data visualizations, to facilitate decision-making and strategic planning by the management team.

# %% [markdown]
# ## Q9. Load the Google Playstore dataset and examine its dimensions. How many rows and columns does the dataset have?

# %%
import pandas as pd

df=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Q10. How does the rating of apps vary by category? Create a boxplot to compare the ratings of different app categories.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a boxplot of ratings by app category
sns.boxplot(x='Category', y='Rating', data=df)
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.title('Ratings of Apps by Category')
plt.xlabel('App Category')
plt.ylabel('Rating')
plt.show()

# %% [markdown]
# ## Q11. Are there any missing values in the dataset? Identify any missing values and describe how they may impact your analysis.

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# Missing values in the dataset can impact the analysis in several ways. They can lead to inaccurate or incomplete results, as missing values may introduce bias or reduce the representativeness of the data.

# %% [markdown]
# ## Q12. What is the relationship between the size of an app and its rating? Create a scatter plot to visualize the relationship.

# %%
import matplotlib.pyplot as plt

# Create a scatter plot of app size vs rating
plt.scatter(df['Size'], df['Rating'])
plt.title('App Size vs Rating')
plt.xlabel('App Size')
plt.ylabel('Rating')
plt.show()

# %% [markdown]
# ## Q13. How does the type of app affect its price? Create a bar chart to compare average prices by app type.

# %%
import numpy as np

# Create a bar chart of average prices by app type
sns.barplot(x='Type', y='Price', data=df, estimator=np.mean)
plt.title('Average Prices of Apps by Type')
plt.xlabel('App Type')
plt.ylabel('Average Price')
plt.show()

# %% [markdown]
# ## Q14. What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps with the highest number of installs.

# %%
df['Installs']=df['Installs'].replace('Free',np.nan)

# Extract the numeric part of the 'Installs' column
df['Installs'] = df['Installs'].str.replace('[+,]', '').astype(float)

# Sort the dataset by number of installs in descending order
df_sorted = df.sort_values(by='Installs', ascending=False)

# Create a frequency table of apps with the highest number of installs
top_10_apps = df_sorted.head(10)

# Display the frequency table
print(top_10_apps[['App', 'Installs']])
# Out:
#                                            App      Installs
# 3896                            Subway Surfers  1.000000e+09
# 3943                                  Facebook  1.000000e+09
# 335   Messenger – Text and Video Chat for Free  1.000000e+09
# 3523                              Google Drive  1.000000e+09
# 3565                              Google Drive  1.000000e+09
# 2884                             Google Photos  1.000000e+09
# 3665                                   YouTube  1.000000e+09
# 2853                             Google Photos  1.000000e+09
# 4234             Skype - free IM & video calls  1.000000e+09
# 3687                   Google Play Movies & TV  1.000000e+09
# /tmp/ipykernel_4904/2737763065.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Installs'] = df['Installs'].str.replace('[+,]', '').astype(float)

# %% [markdown]
# ## Q15. A company wants to launch a new app on the Google Playstore and has asked you to analyze the Google Playstore dataset to identify the most popular app categories. How would you approach this task, and what features would you analyze to make recommendations to the company?

# %% [markdown]
# To identify the most popular app categories in the Google Playstore dataset, I would approach the task by analyzing several features, such as 'Category', 'Installs', 'Rating', and 'Reviews'. Here are some steps I would take:
#
# Data exploration: I would start by exploring the 'Category' feature, which represents the app categories, to understand the distribution of apps in each category. I would create visualizations, such as bar charts or pie charts, to show the number or percentage of apps in each category.
#
# Installations analysis: I would analyze the 'Installs' feature to identify the app categories with the highest number of installations. I would create frequency tables, bar charts, or other visualizations to show the distribution of app installations across different categories, and identify the categories with the highest average or total number of installs.
#
# Rating analysis: I would analyze the 'Rating' feature to identify the app categories with the highest average ratings. I would create visualizations, such as box plots or bar charts, to show the distribution of ratings across different categories, and identify the categories with the highest average ratings.
#
# Reviews analysis: I would analyze the 'Reviews' feature to identify the app categories with the highest number of reviews. I would create frequency tables, bar charts, or other visualizations to show the distribution of reviews across different categories, and identify the categories with the highest total number of reviews.
#
# Recommendations: Based on the above analysis, I would make recommendations to the company on the most popular app categories in the Google Playstore dataset. I would consider factors such as high number of installs, high ratings, and high number of reviews to identify the categories that are likely to be popular among users. The company can use this information to guide their decision on the app category for their new app launch, considering factors such as market demand, competition, and potential user engagement.

# %% [markdown]
# ## Q16. A mobile app development company wants to analyze the Google Playstore dataset to identify the most successful app developers. What features would you analyze to make recommendations to the company, and what data visualizations would you use to present your findings?

# %% [markdown]
# To identify the most successful app developers in the Google Playstore dataset, I would analyze several features that could indicate the success of an app, such as 'App Developer', 'Installs', 'Ratings', 'Reviews', and 'Category'. Here are some steps I would take:
#
# Data exploration: I would start by exploring the 'App Developer' feature, which represents the developer of each app, to understand the distribution of apps developed by different developers. I would create visualizations, such as bar charts or pie charts, to show the number or percentage of apps developed by each developer.
#
# Installations analysis: I would analyze the 'Installs' feature to identify the app developers with the highest total number of app installations. I would create frequency tables, bar charts, or other visualizations to show the distribution of app installations across different developers, and identify the developers with the highest total number of installs.
#
# Rating analysis: I would analyze the 'Ratings' feature to identify the app developers with the highest average ratings. I would create visualizations, such as box plots or bar charts, to show the distribution of ratings across different developers, and identify the developers with the highest average ratings.
#
# Reviews analysis: I would analyze the 'Reviews' feature to identify the app developers with the highest number of reviews. I would create frequency tables, bar charts, or other visualizations to show the distribution of reviews across different developers, and identify the developers with the highest total number of reviews.
#
# Category analysis: I would analyze the 'Category' feature to identify the app developers who have developed apps in the most popular categories. I would create visualizations, such as bar charts or pie charts, to show the number or percentage of apps developed by each developer in different categories, and identify the developers who have developed apps in the most popular categories.
#
# Recommendations: Based on the above analysis, I would make recommendations to the mobile app development company on the most successful app developers in the Google Playstore dataset. I would consider factors such as high number of installs, high ratings, high number of reviews, and apps developed in popular categories to identify the developers who have demonstrated success in the past. The company can use this information to guide their decision on potential partnerships or collaborations with app developers for their future app development projects. Data visualizations such as bar charts, pie charts, and box plots can be used to present the findings in an easily understandable and visually appealing manner.

# %% [markdown]
# ## Q17. A marketing research firm wants to analyze the Google Playstore dataset to identify the best time to launch a new app. What features would you analyze to make recommendations to the company, and what data visualizations would you use to present your findings?

# %% [markdown]
# To identify the best time to launch a new app in the Google Playstore, I would analyze several features that could indicate the seasonality or trend of app downloads, such as 'Month', 'Installs', 'Category', and 'Reviews'. Here are some steps I would take:
#
# Data exploration: I would start by exploring the 'Month' feature, which represents the month of app release or update, to understand the distribution of app downloads across different months. I would create visualizations, such as line charts or bar charts, to show the number or percentage of app downloads in each month.
#
# Installations analysis: I would analyze the 'Installs' feature to identify the months with the highest number of app installations. I would create frequency tables, bar charts, or other visualizations to show the distribution of app installations across different months, and identify the months with the highest total number of installs.
#
# Category analysis: I would analyze the 'Category' feature to identify the app categories that are popular or have high demand during specific months. I would create visualizations, such as bar charts or line charts, to show the number or percentage of app downloads in each category for different months, and identify the categories with higher downloads during specific months.
#
# Reviews analysis: I would analyze the 'Reviews' feature to understand user feedback and sentiments for apps launched in different months. I would create visualizations, such as word clouds or sentiment analysis charts, to show the most common keywords or sentiments in user reviews for apps launched in different months. This could provide insights into the overall user satisfaction and feedback for apps launched during different times of the year.
#
# Recommendations: Based on the above analysis, I would make recommendations to the marketing research firm on the best time to launch a new app in the Google Playstore. I would consider factors such as high number of installs during specific months, popularity of app categories during different times of the year, and user feedback from reviews. The firm can use this information to guide their decision on the optimal timing for launching a new app to maximize downloads and user engagement. Data visualizations such as line charts, bar charts, word clouds, and sentiment analysis charts can be used to present the findings in an easily understandable and visually appealing manner.
