# %% [markdown]
# ## Q1: What is Estimation Statistics? Explain point estimate and interval estimate.

# %% [markdown]
# Estimation Statistics involves using a sample of data to make inferences or estimates about the population from which the sample was taken. Point estimate refers to a single numerical value that is used to estimate a population parameter, such as the sample mean used to estimate the population mean. Interval estimate refers to a range of values within which the true population parameter is likely to lie, such as a confidence interval.

# %% [markdown]
# ## Q2. Write a Python function to estimate the population mean using a sample mean and standard deviation.

# %%
def estimate_population_mean(sample_mean, sample_std_dev, sample_size):
    standard_error = sample_std_dev / (sample_size ** 0.5)
    margin_of_error = 1.96 * standard_error # for a 95% confidence interval
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error
    return (lower_bound, upper_bound)

# %% [markdown]
# ## Q3: What is Hypothesis testing? Why is it used? State the importance of Hypothesis testing.

# %% [markdown]
# Hypothesis testing is a statistical technique used to determine if there is sufficient evidence to reject or fail to reject a null hypothesis about a population parameter. It is used to make decisions about the population based on sample data. The importance of hypothesis testing lies in its ability to provide a structured approach to making decisions about population parameters, and to provide a level of certainty about the results obtained.

# %% [markdown]
# ## Q4. Create a hypothesis that states whether the average weight of male college students is greater than the average weight of female college students.

# %% [markdown]
# The average weight of male college students is equal to the average weight of female college students. Alternative hypothesis: The average weight of male college students is greater than the average weight of female college students.

# %% [markdown]
# ## Q5. Write a Python script to conduct a hypothesis test on the difference between two population means, given a sample from each population.

# %%
import numpy as np
from scipy.stats import ttest_ind

sample_1 = np.array([1, 2, 3, 4, 5])
sample_2 = np.array([6, 7, 8, 9, 10])

t_stat, p_value = ttest_ind(sample_1, sample_2)

if p_value < 0.05:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# Reject null hypothesis

# %% [markdown]
# ## Q6: What is a null and alternative hypothesis? Give some examples.

# %% [markdown]
# In hypothesis testing, the null hypothesis is a statement that there is no significant difference between a population parameter and a sample statistic. The alternative hypothesis is a statement that there is a significant difference between a population parameter and a sample statistic.
#
# Examples of null and alternative hypotheses:
#
# Null hypothesis: The mean height of adult males in the United States is 70 inches.
# Alternative hypothesis: The mean height of adult males in the United States is not 70 inches.
#
# Null hypothesis: There is no significant difference in the proportion of males and females who prefer coffee.
# Alternative hypothesis: There is a significant difference in the proportion of males and females who prefer coffee.

# %% [markdown]
# ## Q7: Write down the steps involved in hypothesis testing.

# %% [markdown]
#  - Formulate null and alternative hypotheses.
#  - Determine the level of significance.
#  - Collect sample data.
#  - Compute a test statistic.
#  - Determine the p-value.
#  - Make a decision and interpret results.

# %% [markdown]
# ## Q8. Define p-value and explain its significance in hypothesis testing.

# %% [markdown]
# The p-value is the probability of obtaining a test statistic as extreme or more extreme than the observed value, assuming the null hypothesis is true. In hypothesis testing, the p-value is used to determine the strength of evidence against the null hypothesis. A small p-value (less than the level of significance) suggests strong evidence against the null hypothesis, while a large p-value suggests weak evidence against the null hypothesis.

# %% [markdown]
# ## Q9. Generate a Student's t-distribution plot using Python's matplotlib library, with the degrees of freedom parameter set to 10.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import t

df = 10
x = np.linspace(t.ppf(0.001, df), t.ppf(0.999, df), 100)
plt.plot(x, t.pdf(x, df))
plt.title("Student's t-distribution with 10 degrees of freedom")
plt.xlabel("x")
plt.ylabel("pdf(x)")
plt.show()

# %% [markdown]
# ## Q10. Write a Python program to calculate the two-sample t-test for independent samples, given two random samples of equal size and a null hypothesis that the population means are equal.

# %%
import numpy as np
from scipy.stats import ttest_ind

# Generate two random samples
sample1 = np.random.normal(10, 2, size=50)
sample2 = np.random.normal(12, 2, size=50)

# Perform two-sample t-test
t_stat, p_value = ttest_ind(sample1, sample2)

# Print results
print("t-statistic =", t_stat)
print("p-value =", p_value)
# Out:
# t-statistic = -5.004443796062963
# p-value = 2.4678590827775747e-06

# %% [markdown]
# ## Q11: What is Student’s t distribution? When to use the t-Distribution.

# %% [markdown]
# The Student's t-distribution is a probability distribution that is used to estimate population parameters when the sample size is small or the population standard deviation is unknown. It is used in situations where the sample size is less than 30 and the population standard deviation is unknown. The t-distribution is similar to the standard normal distribution, but has heavier tails and a flatter peak.

# %% [markdown]
# ## Q12: What is t-statistic? State the formula for t-statistic.

# %% [markdown]
# The t-statistic is a measure of the difference between the sample mean and the hypothesized population mean, measured in units of the standard error of the sample mean. The formula for the t-statistic is:
# -   t = (x - mu) / (s / sqrt(n))
#
# where x is the sample mean, mu is the hypothesized population mean, s is the sample standard deviation, and n is the sample size.

# %% [markdown]
# ## Q13. A coffee shop owner wants to estimate the average daily revenue for their shop. They take a random sample of 50 days and find the sample mean revenue to be 500 with a standard deviation of 50. Estimate the population mean revenue with a 95% confidence interval.

# %% [markdown]
#  To estimate the population mean revenue with a 95% confidence interval, we can use the following formula:
#
# - CI = x ± t(alpha/2, n-1) * (s / sqrt(n))
#
# where x is the sample mean revenue, s is the sample standard deviation, n is the sample size, alpha is the significance level (0.05 for 95% confidence interval), and t(alpha/2, n-1) is the t-value with n-1 degrees of freedom corresponding to the given alpha/2 value (0.025 for 95% confidence interval).
#
# - CI = 500 ± t(0.025, 49) * (50 / sqrt(50))
#
# - CI = 500 ± 2.009 * (50 / sqrt(50))
#      = 500

# %% [markdown]
# ## Q14. A researcher hypothesizes that a new drug will decrease blood pressure by 10 mmHg. They conduct a clinical trial with 100 patients and find that the sample mean decrease in blood pressure is 8 mmHg with a standard deviation of 3 mmHg. Test the hypothesis with a significance level of 0.05.

# %% [markdown]
# o test the hypothesis that the new drug will decrease blood pressure by 10 mmHg, the researcher can use a one-sample t-test. The null hypothesis is that the mean decrease in blood pressure is equal to 10 mmHg, and the alternative hypothesis is that the mean decrease in blood pressure is less than 10 mmHg. Using a significance level of 0.05, the critical t-value with 99 degrees of freedom is -1.66 (from a t-distribution table or calculator). The t-statistic for the sample is calculated as:
#
# t = (sample mean - hypothesized mean) / (sample standard deviation / sqrt(sample size))
# t = (8 - 10) / (3 / sqrt(100))
# t = -2.67
#
# Since the t-statistic (-2.67) is less than the critical t-value (-1.66), we reject the null hypothesis and conclude that there is evidence to support the alternative hypothesis. Therefore, the clinical trial suggests that the new drug decreases blood pressure by less than 10 mmHg.

# %% [markdown]
# ## Q15. An electronics company produces a certain type of product with a mean weight of 5 pounds and a standard deviation of 0.5 pounds. A random sample of 25 products is taken, and the sample mean weight is found to be 4.8 pounds. Test the hypothesis that the true mean weight of the products is less than 5 pounds with a significance level of 0.01.

# %% [markdown]
# To test the hypothesis that the true mean weight of the products is less than 5 pounds, the company can use a one-sample t-test. The null hypothesis is that the mean weight is equal to 5 pounds, and the alternative hypothesis is that the mean weight is less than 5 pounds. Using a significance level of 0.01, the critical t-value with 24 degrees of freedom (n-1) is -2.492 (from a t-distribution table or calculator). The t-statistic for the sample is calculated as:
#
# t = (sample mean - hypothesized mean) / (sample standard deviation / sqrt(sample size))
# t = (4.8 - 5) / (0.5 / sqrt(25))
# t = -2
#
# Since the t-statistic (-2) is less than the critical t-value (-2.492), we reject the null hypothesis and conclude that there is evidence to support the alternative hypothesis. Therefore, the sample suggests that the true mean weight of the products is less than 5 pounds.

# %% [markdown]
# ## Q16. Two groups of students are given different study materials to prepare for a test. The first group (n1 = 30) has a mean score of 80 with a standard deviation of 10, and the second group (n2 = 40) has a mean score of 75 with a standard deviation of 8. Test the hypothesis that the population means for the two groups are equal with a significance level of 0.01.

# %% [markdown]
# To test the hypothesis that the population means for the two groups are equal, the researcher can use a two-sample t-test. The null hypothesis is that the mean score for group 1 is equal to the mean score for group 2, and the alternative hypothesis is that the means are not equal. Using a significance level of 0.01 and assuming equal variances, the critical t-value with 68 degrees of freedom is +/- 2.646 (from a t-distribution table or calculator). The pooled standard deviation is calculated as:
#
# s_pooled = sqrt(((n1-1)s1^2 + (n2-1)s2^2) / (n1+n2-2))
# s_pooled = sqrt(((2910^2) + (398^2)) / (30+40-2))
# s_pooled = 9.075
#
# The t-statistic for the sample is calculated as:
#
# t = (sample mean 1 - sample mean 2) / (s_pooled * sqrt(1/n1 + 1/n2))
# t = (80 - 75) / (9.075 * sqrt(1/30 + 1/40))
# t = 2.08
#
# Since the absolute value of the t-statistic (2.08) is greater than the critical t-value (2.646), we fail to reject the null hypothesis and conclude that there is not enough evidence to support the alternative hypothesis. Therefore, the sample does not suggest that the population means for the two groups are different.

# %% [markdown]
# ## Q17. A marketing company wants to estimate the average number of ads watched by viewers during a TV program. They take a random sample of 50 viewers and find that the sample mean is 4 with a standard deviation of 1.5. Estimate the population mean with a 99% confidence interval.

# %% [markdown]
# To estimate the population mean with a 99% confidence interval, we can use the following formula:
#
# Confidence Interval = sample mean ± (Z-score)*(standard deviation/sqrt(sample size))
#
# where Z-score is the critical value for the confidence level, which can be found using a Z-table or calculator.
#
# For a 99% confidence interval, the Z-score is 2.576.
#
# Plugging in the values from the problem, we get:
#
# Confidence Interval = 4 ± (2.576)*(1.5/sqrt(50))
#
# Simplifying this expression, we get:
#
# Confidence Interval = 4 ± 0.618
#
# Therefore, the 99% confidence interval for the population mean number of ads watched during a TV program is (3.382, 4.618). We can be 99% confident that the true population mean falls within this interval.
